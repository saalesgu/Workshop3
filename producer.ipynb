# %%
# Data Handling
# ======================================================================
import pandas as pd

# Utility Functions
# ======================================================================
from utils.years_functions import *

# Logging and Event Handling
# ======================================================================
import logging as log

# Serialization and Deserialization
# ======================================================================
import json

# Kafka Producer
# ======================================================================
from kafka import KafkaProducer

# Time Handling
# ======================================================================
import time

# Machine Learning
# ======================================================================
from sklearn.model_selection import train_test_split

# %%
log.basicConfig(level=log.INFO)

# %%
# Load Datasets
data = load_datasets('data')

df_2015 = data[2015]
df_2016 = data[2016]
df_2017 = data[2017]
df_2018 = data[2018]
df_2019 = data[2019]

# Data Cleaning
df_2018 = df_2018.dropna()

# Data Transformation
normalize_columns = normalize_column_names({2015: df_2015, 2016: df_2016, 2017: df_2017, 2018: df_2018, 2019: df_2019})
year_column = add_year_column(normalize_columns)

df_2015 = normalize_columns[2015]
df_2016 = normalize_columns[2016]
df_2017 = normalize_columns[2017]
df_2018 = normalize_columns[2018]
df_2019 = normalize_columns[2019]

# Concatenate DataFrames

concatenated_df = concatenate_common_columns({2015: df_2015, 2016: df_2016, 2017: df_2017, 2018: df_2018, 2019: df_2019})

# Concatenate DataFrame Transformation
concatenated_df = map_country_to_continent(concatenated_df)

concatenated_df = pd.get_dummies(concatenated_df, columns=['Continent'] ,dtype=int)
concatenated_df.drop(columns=['Country', 'Happiness_Rank'], axis=1, inplace=True)

new_columns = {
    'Continent_North America' : 'Continent_North_America',
    'Continent_South America' : 'Continent_South_America'
}

concatenated_df.rename(columns=new_columns, inplace=True)

# Add interactions between columns

concatenated_df['Economy_Health'] = concatenated_df['Economy'] * concatenated_df['Health']
concatenated_df['Trust_Freedom'] = concatenated_df['Trust'] * concatenated_df['Freedom']
concatenated_df['Economy_Trust'] = concatenated_df['Economy'] * concatenated_df['Trust']
concatenated_df['Trust_Health'] = concatenated_df['Trust'] * concatenated_df['Health']

# Train and Test Split

X = concatenated_df.drop(columns=['Happiness_Score'], axis=1)
y = concatenated_df['Happiness_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=52)

log.info('Data Preprocessing Completed')
# Out:
# INFO:root:Loaded 5 datasets
# INFO:root:Column names normalized
# INFO:root:Data Preprocessing Completed

# %%
X_test['Happiness_Score'] = y_test
X_test.head(2)
# Out:
#      Trust  Economy  Social_Support  Freedom  Generosity  Year  Health  \
# 672  0.005    1.162           1.232    0.462       0.083  2019   0.825
# 735  0.072    0.450           1.134    0.292       0.153  2019   0.571
#
#      Continent_Africa  Continent_Asia  Continent_Europe  \
# 672                 0               0                 1
# 735                 1               0                 0
#
#      Continent_North_America  Continent_Oceania  Continent_South_America  \
# 672                        0                  0                        0
# 735                        0                  0                        0
#
#      Economy_Health  Trust_Freedom  Economy_Trust  Trust_Health  \
# 672         0.95865       0.002310        0.00581      0.004125
# 735         0.25695       0.021024        0.03240      0.041112
#
#      Happiness_Score
# 672            6.070
# 735            4.681

# %%
X_test.insert(0, 'id', X_test.index + 1)

# %%
length_dataset(X_test)
X_test.head(2)
# Out:
# Number of Row : 235
# Number of Columns : 19
# -------------------------Structure of the DataFrame------------------------
#       id  Trust  Economy  Social_Support  Freedom  Generosity  Year  Health  \
# 672  673  0.005    1.162           1.232    0.462       0.083  2019   0.825
# 735  736  0.072    0.450           1.134    0.292       0.153  2019   0.571
#
#      Continent_Africa  Continent_Asia  Continent_Europe  \
# 672                 0               0                 1
# 735                 1               0                 0
#
#      Continent_North_America  Continent_Oceania  Continent_South_America  \
# 672                        0                  0                        0
# 735                        0                  0                        0
#
#      Economy_Health  Trust_Freedom  Economy_Trust  Trust_Health  \
# 672         0.95865       0.002310        0.00581      0.004125
# 735         0.25695       0.021024        0.03240      0.041112
#
#      Happiness_Score
# 672            6.070
# 735            4.681

# %%
column_order = ['id', 'Social_Support', 'Year', 'Trust', 'Generosity','Health', 'Economy', 'Freedom', 'Happiness_Score', 'Continent_Africa', 'Continent_Asia', 'Continent_Europe', 'Continent_North_America', 'Continent_Oceania', 'Continent_South_America', 'Economy_Health', 'Trust_Freedom', 'Economy_Trust','Trust_Health']
X_test = X_test[column_order]

# %%
producer = KafkaProducer(bootstrap_servers='localhost:9092',
                        value_serializer=lambda v: json.dumps(v).encode('utf-8'))

for index, row in X_test.iterrows():
    dict_row = dict(row)
    json_row = json.dumps(dict_row)
    producer.send('prueba-2', value=json_row)
    time.sleep(0.2)
    formatted_time = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())
    log.info(f'Message sent at {formatted_time}')

log.info('All messages sent')
# Out:
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# INFO:kafka.conn:Probing node bootstrap-0 broker version
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# INFO:kafka.conn:Broker version identified as 2.5.0
# INFO:kafka.conn:Set configuration api_version=(2, 5, 0) to skip auto check_version requests on startup
# INFO:kafka.conn:<BrokerConnection node_id=1 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# INFO:kafka.conn:<BrokerConnection node_id=1 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# INFO:root:Message sent at 2024-05-10 22:33:59
# INFO:root:Message sent at 2024-05-10 22:33:59
# INFO:root:Message sent at 2024-05-10 22:33:59
# INFO:root:Message sent at 2024-05-10 22:33:59
# INFO:root:Message sent at 2024-05-10 22:34:00
# INFO:root:Message sent at 2024-05-10 22:34:00
# INFO:root:Message sent at 2024-05-10 22:34:00
# INFO:root:Message sent at 2024-05-10 22:34:00
# INFO:root:Message sent at 2024-05-10 22:34:00
# INFO:root:Message sent at 2024-05-10 22:34:01
# INFO:root:Message sent at 2024-05-10 22:34:01
# INFO:root:Message sent at 2024-05-10 22:34:01
# INFO:root:Message sent at 2024-05-10 22:34:01
# INFO:root:Message sent at 2024-05-10 22:34:01
# INFO:root:Message sent at 2024-05-10 22:34:02
# INFO:root:Message sent at 2024-05-10 22:34:02
# INFO:root:Message sent at 2024-05-10 22:34:02
# INFO:root:Message sent at 2024-05-10 22:34:02
# INFO:root:Message sent at 2024-05-10 22:34:03
# INFO:root:Message sent at 2024-05-10 22:34:03
# INFO:root:Message sent at 2024-05-10 22:34:03
# INFO:root:Message sent at 2024-05-10 22:34:03
# INFO:root:Message sent at 2024-05-10 22:34:03
# INFO:root:Message sent at 2024-05-10 22:34:04
# INFO:root:Message sent at 2024-05-10 22:34:04
# INFO:root:Message sent at 2024-05-10 22:34:04
# INFO:root:Message sent at 2024-05-10 22:34:04
# INFO:root:Message sent at 2024-05-10 22:34:04
# INFO:root:Message sent at 2024-05-10 22:34:05
# INFO:root:Message sent at 2024-05-10 22:34:05
# INFO:root:Message sent at 2024-05-10 22:34:05
# INFO:root:Message sent at 2024-05-10 22:34:05
# INFO:root:Message sent at 2024-05-10 22:34:05
# INFO:root:Message sent at 2024-05-10 22:34:06
# INFO:root:Message sent at 2024-05-10 22:34:06
# INFO:root:Message sent at 2024-05-10 22:34:06
# INFO:root:Message sent at 2024-05-10 22:34:06
# INFO:root:Message sent at 2024-05-10 22:34:06
# INFO:root:Message sent at 2024-05-10 22:34:07
# INFO:root:Message sent at 2024-05-10 22:34:07
# INFO:root:Message sent at 2024-05-10 22:34:07
# INFO:root:Message sent at 2024-05-10 22:34:07
# INFO:root:Message sent at 2024-05-10 22:34:08
# INFO:root:Message sent at 2024-05-10 22:34:08
# INFO:root:Message sent at 2024-05-10 22:34:08
# INFO:root:Message sent at 2024-05-10 22:34:08
# INFO:root:Message sent at 2024-05-10 22:34:08
# INFO:root:Message sent at 2024-05-10 22:34:09
# INFO:root:Message sent at 2024-05-10 22:34:09
# INFO:root:Message sent at 2024-05-10 22:34:09
# INFO:root:Message sent at 2024-05-10 22:34:09
# INFO:root:Message sent at 2024-05-10 22:34:09
# INFO:root:Message sent at 2024-05-10 22:34:10
# INFO:root:Message sent at 2024-05-10 22:34:10
# INFO:root:Message sent at 2024-05-10 22:34:10
# INFO:root:Message sent at 2024-05-10 22:34:10
# INFO:root:Message sent at 2024-05-10 22:34:10
# INFO:root:Message sent at 2024-05-10 22:34:11
# INFO:root:Message sent at 2024-05-10 22:34:11
# INFO:root:Message sent at 2024-05-10 22:34:11
# INFO:root:Message sent at 2024-05-10 22:34:11
# INFO:root:Message sent at 2024-05-10 22:34:12
# INFO:root:Message sent at 2024-05-10 22:34:12
# INFO:root:Message sent at 2024-05-10 22:34:12
# INFO:root:Message sent at 2024-05-10 22:34:12
# INFO:root:Message sent at 2024-05-10 22:34:12
# INFO:root:Message sent at 2024-05-10 22:34:13
# INFO:root:Message sent at 2024-05-10 22:34:13
# INFO:root:Message sent at 2024-05-10 22:34:13
# INFO:root:Message sent at 2024-05-10 22:34:13
# INFO:root:Message sent at 2024-05-10 22:34:13
# INFO:root:Message sent at 2024-05-10 22:34:14
# INFO:root:Message sent at 2024-05-10 22:34:14
# INFO:root:Message sent at 2024-05-10 22:34:14
# INFO:root:Message sent at 2024-05-10 22:34:14
# INFO:root:Message sent at 2024-05-10 22:34:14
# INFO:root:Message sent at 2024-05-10 22:34:15
# INFO:root:Message sent at 2024-05-10 22:34:15
# INFO:root:Message sent at 2024-05-10 22:34:15
# INFO:root:Message sent at 2024-05-10 22:34:15
# INFO:root:Message sent at 2024-05-10 22:34:16
# INFO:root:Message sent at 2024-05-10 22:34:16
# INFO:root:Message sent at 2024-05-10 22:34:16
# INFO:root:Message sent at 2024-05-10 22:34:16
# INFO:root:Message sent at 2024-05-10 22:34:16
# INFO:root:Message sent at 2024-05-10 22:34:17
# INFO:root:Message sent at 2024-05-10 22:34:17
# INFO:root:Message sent at 2024-05-10 22:34:17
# INFO:root:Message sent at 2024-05-10 22:34:17
# INFO:root:Message sent at 2024-05-10 22:34:17
# INFO:root:Message sent at 2024-05-10 22:34:18
# INFO:root:Message sent at 2024-05-10 22:34:18
# INFO:root:Message sent at 2024-05-10 22:34:18
# INFO:root:Message sent at 2024-05-10 22:34:18
# INFO:root:Message sent at 2024-05-10 22:34:19
# INFO:root:Message sent at 2024-05-10 22:34:19
# INFO:root:Message sent at 2024-05-10 22:34:19
# INFO:root:Message sent at 2024-05-10 22:34:19
# INFO:root:Message sent at 2024-05-10 22:34:19
# INFO:root:Message sent at 2024-05-10 22:34:20
# INFO:root:Message sent at 2024-05-10 22:34:20
# INFO:root:Message sent at 2024-05-10 22:34:20
# INFO:root:Message sent at 2024-05-10 22:34:20
# INFO:root:Message sent at 2024-05-10 22:34:20
# INFO:root:Message sent at 2024-05-10 22:34:21
# INFO:root:Message sent at 2024-05-10 22:34:21
# INFO:root:Message sent at 2024-05-10 22:34:21
# INFO:root:Message sent at 2024-05-10 22:34:21
# INFO:root:Message sent at 2024-05-10 22:34:21
# INFO:root:Message sent at 2024-05-10 22:34:22
# INFO:root:Message sent at 2024-05-10 22:34:22
# INFO:root:Message sent at 2024-05-10 22:34:22
# INFO:root:Message sent at 2024-05-10 22:34:22
# INFO:root:Message sent at 2024-05-10 22:34:23
# INFO:root:Message sent at 2024-05-10 22:34:23
# INFO:root:Message sent at 2024-05-10 22:34:23
# INFO:root:Message sent at 2024-05-10 22:34:23
# INFO:root:Message sent at 2024-05-10 22:34:23
# INFO:root:Message sent at 2024-05-10 22:34:24
# INFO:root:Message sent at 2024-05-10 22:34:24
# INFO:root:Message sent at 2024-05-10 22:34:24
# INFO:root:Message sent at 2024-05-10 22:34:24
# INFO:root:Message sent at 2024-05-10 22:34:24
# INFO:root:Message sent at 2024-05-10 22:34:25
# INFO:root:Message sent at 2024-05-10 22:34:25
# INFO:root:Message sent at 2024-05-10 22:34:25
# INFO:root:Message sent at 2024-05-10 22:34:25
# INFO:root:Message sent at 2024-05-10 22:34:25
# INFO:root:Message sent at 2024-05-10 22:34:26
# INFO:root:Message sent at 2024-05-10 22:34:26
# INFO:root:Message sent at 2024-05-10 22:34:26
# INFO:root:Message sent at 2024-05-10 22:34:26
# INFO:root:Message sent at 2024-05-10 22:34:26
# INFO:root:Message sent at 2024-05-10 22:34:27
# INFO:root:Message sent at 2024-05-10 22:34:27
# INFO:root:Message sent at 2024-05-10 22:34:27
# INFO:root:Message sent at 2024-05-10 22:34:27
# INFO:root:Message sent at 2024-05-10 22:34:28
# INFO:root:Message sent at 2024-05-10 22:34:28
# INFO:root:Message sent at 2024-05-10 22:34:28
# INFO:root:Message sent at 2024-05-10 22:34:28
# INFO:root:Message sent at 2024-05-10 22:34:28
# INFO:root:Message sent at 2024-05-10 22:34:29
# INFO:root:Message sent at 2024-05-10 22:34:29
# INFO:root:Message sent at 2024-05-10 22:34:29
# INFO:root:Message sent at 2024-05-10 22:34:29
# INFO:root:Message sent at 2024-05-10 22:34:29
# INFO:root:Message sent at 2024-05-10 22:34:30
# INFO:root:Message sent at 2024-05-10 22:34:30
# INFO:root:Message sent at 2024-05-10 22:34:30
# INFO:root:Message sent at 2024-05-10 22:34:30
# INFO:root:Message sent at 2024-05-10 22:34:31
# INFO:root:Message sent at 2024-05-10 22:34:31
# INFO:root:Message sent at 2024-05-10 22:34:31
# INFO:root:Message sent at 2024-05-10 22:34:31
# INFO:root:Message sent at 2024-05-10 22:34:31
# INFO:root:Message sent at 2024-05-10 22:34:32
# INFO:root:Message sent at 2024-05-10 22:34:32
# INFO:root:Message sent at 2024-05-10 22:34:32
# INFO:root:Message sent at 2024-05-10 22:34:32
# INFO:root:Message sent at 2024-05-10 22:34:32
# INFO:root:Message sent at 2024-05-10 22:34:33
# INFO:root:Message sent at 2024-05-10 22:34:33
# INFO:root:Message sent at 2024-05-10 22:34:33
# INFO:root:Message sent at 2024-05-10 22:34:33
# INFO:root:Message sent at 2024-05-10 22:34:33
# INFO:root:Message sent at 2024-05-10 22:34:34
# INFO:root:Message sent at 2024-05-10 22:34:34
# INFO:root:Message sent at 2024-05-10 22:34:34
# INFO:root:Message sent at 2024-05-10 22:34:34
# INFO:root:Message sent at 2024-05-10 22:34:35
# INFO:root:Message sent at 2024-05-10 22:34:35
# INFO:root:Message sent at 2024-05-10 22:34:35
# INFO:root:Message sent at 2024-05-10 22:34:35
# INFO:root:Message sent at 2024-05-10 22:34:35
# INFO:root:Message sent at 2024-05-10 22:34:36
# INFO:root:Message sent at 2024-05-10 22:34:36
# INFO:root:Message sent at 2024-05-10 22:34:36
# INFO:root:Message sent at 2024-05-10 22:34:36
# INFO:root:Message sent at 2024-05-10 22:34:36
# INFO:root:Message sent at 2024-05-10 22:34:37
# INFO:root:Message sent at 2024-05-10 22:34:37
# INFO:root:Message sent at 2024-05-10 22:34:37
# INFO:root:Message sent at 2024-05-10 22:34:37
# INFO:root:Message sent at 2024-05-10 22:34:38
# INFO:root:Message sent at 2024-05-10 22:34:38
# INFO:root:Message sent at 2024-05-10 22:34:38
# INFO:root:Message sent at 2024-05-10 22:34:38
# INFO:root:Message sent at 2024-05-10 22:34:38
# INFO:root:Message sent at 2024-05-10 22:34:39
# INFO:root:Message sent at 2024-05-10 22:34:39
# INFO:root:Message sent at 2024-05-10 22:34:39
# INFO:root:Message sent at 2024-05-10 22:34:39
# INFO:root:Message sent at 2024-05-10 22:34:39
# INFO:root:Message sent at 2024-05-10 22:34:40
# INFO:root:Message sent at 2024-05-10 22:34:40
# INFO:root:Message sent at 2024-05-10 22:34:40
# INFO:root:Message sent at 2024-05-10 22:34:40
# INFO:root:Message sent at 2024-05-10 22:34:40
# INFO:root:Message sent at 2024-05-10 22:34:41
# INFO:root:Message sent at 2024-05-10 22:34:41
# INFO:root:Message sent at 2024-05-10 22:34:41
# INFO:root:Message sent at 2024-05-10 22:34:41
# INFO:root:Message sent at 2024-05-10 22:34:42
# INFO:root:Message sent at 2024-05-10 22:34:42
# INFO:root:Message sent at 2024-05-10 22:34:42
# INFO:root:Message sent at 2024-05-10 22:34:42
# INFO:root:Message sent at 2024-05-10 22:34:42
# INFO:root:Message sent at 2024-05-10 22:34:43
# INFO:root:Message sent at 2024-05-10 22:34:43
# INFO:root:Message sent at 2024-05-10 22:34:43
# INFO:root:Message sent at 2024-05-10 22:34:43
# INFO:root:Message sent at 2024-05-10 22:34:43
# INFO:root:Message sent at 2024-05-10 22:34:44
# INFO:root:Message sent at 2024-05-10 22:34:44
# INFO:root:Message sent at 2024-05-10 22:34:44
# INFO:root:Message sent at 2024-05-10 22:34:44
# INFO:root:Message sent at 2024-05-10 22:34:44
# INFO:root:Message sent at 2024-05-10 22:34:45
# INFO:root:Message sent at 2024-05-10 22:34:45
# INFO:root:Message sent at 2024-05-10 22:34:45
# INFO:root:Message sent at 2024-05-10 22:34:45
# INFO:root:Message sent at 2024-05-10 22:34:46
# INFO:root:Message sent at 2024-05-10 22:34:46
# INFO:root:Message sent at 2024-05-10 22:34:46
# INFO:root:Message sent at 2024-05-10 22:34:46
# INFO:root:Message sent at 2024-05-10 22:34:46
# INFO:root:Message sent at 2024-05-10 22:34:47
# INFO:root:Message sent at 2024-05-10 22:34:47
# INFO:root:Message sent at 2024-05-10 22:34:47
# INFO:root:Message sent at 2024-05-10 22:34:47
# INFO:root:Message sent at 2024-05-10 22:34:47
# INFO:root:Message sent at 2024-05-10 22:34:48
# INFO:root:Message sent at 2024-05-10 22:34:48
# INFO:root:Message sent at 2024-05-10 22:34:48
# INFO:root:All messages sent
